# %% [markdown]
# Conclusions et recommandations
#
# Objectif : synthétiser et proposer des actions concrètes.
#
# Exemples :
#
# Réviser la politique de remise pour certaines sous-catégories
#
# Prioriser les marchés géographiques rentables
#
# Ajuster le catalogue produit pour améliorer la marge
#
# Intégrer le feedback client dans la stratégie commerciale

# %%
# Résumé des insights clés
print("Certains marchés génèrent beaucoup de ventes mais avec des marges faibles.")
print("Segments Consumer et Corporate sont les plus rentables, Home Office moins.")
print("Les remises élevées réduisent la rentabilité sur certaines sous-catégories.")
print("Certains produits ont des ventes élevées mais des profits négatifs.")
print("Feedback client positif associé à une meilleure performance financière.")

# Recommandations
print("- Optimiser la politique de remises sur certaines sous-catégories")
print("- Prioriser les marchés géographiques rentables")
print("- Ajuster le catalogue produit pour améliorer la marge")
print("- Intégrer le feedback client dans la stratégie commerciale")
